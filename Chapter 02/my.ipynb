# %%
from vector_drawing import *

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4)]
draw(
    Points(*dino_vectors)    
    )

# %%
draw(
    Points(*dino_vectors),    
    Segment((6,4),(3,1))
    )

# %%
draw(Arrow((2,-2)))

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
                (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
                (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)]
draw(
    Points(*dino_vectors),    
    Polygon(*dino_vectors)
    )

# %%
vec = [(x,x**2) for x in range(-10,11)]
draw(Points(*vec),
    grid=(1,10),
    nice_aspect_ratio=False)

# %%
print(vec)
# Out:
# [(-10, 100), (-9, 81), (-8, 64), (-7, 49), (-6, 36), (-5, 25), (-4, 16), (-3, 9), (-2, 4), (-1, 1), (0, 0), (1, 1), (2, 4), (3, 9), (4, 16), (5, 25), (6, 36), (7, 49), (8, 64), (9, 81), (10, 100)]

# %%
from vectors import *
dino_vectors2 = [add((-1.5,-2.5),v) for v in dino_vectors]
draw(
    Polygon(*dino_vectors,color=blue),
    Polygon(*dino_vectors2,color=red)
)

# %%
u = (-2,0)
v = (1.5, 1.5)
w = (4,1)

add(u,v,w)
# Out:
# (3.5, 2.5)

# %%
def translate_rev(translation,*vectors):
    return([add(translation,v) for v in vectors])

# %%
translate((1,1),[(0,0), (0,1), (-3,-3)])
# Out:
# [(1, 1), (1, 2), (-2, -2)]

# %%
import time

# %% [markdown]
# 100 dinos my own code

# %%
# %%time
grd = 10
translation_vector = (12,10)
all_vectors = []

for i in range(grd):
    for j in range(grd):
        trans = translation_vector[0]*i, translation_vector[1]*j
        all_vectors.append(Polygon(*translate(trans,dino_vectors)))

draw(*all_vectors,axes=None,grid=None,origin=None)
# Out:
# CPU times: user 3.73 s, sys: 97.5 ms, total: 3.83 s
# Wall time: 2.56 s

# %% [markdown]
# 100 dinos book code

# %%
# %%time
translation_vector =[ (12*x, 10*y) for x in range(-5,5) for y in range(-5,5)]
dinos = [Polygon(*translate(t,dino_vectors)) for t in translation_vector] 
draw(*dinos,grid=None,axes=None,origin=None)
# Out:
# CPU times: user 3.88 s, sys: 155 ms, total: 4.04 s
# Wall time: 3.07 s
